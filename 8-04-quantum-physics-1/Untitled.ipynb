# %% [markdown]
# EM is a linear theory
# If we have a solution π to EM for a field, then cπ and π_1 + π_2 are also solutions
#
# Schrodinger equation is also linear, with i, so requires complex numbers
#
# Light is a simultaneous electric and magnetic wave
#
# It can be polarized since it is orthogonal transverse wave
#
# QM is non-deterministic since the energy of photon is determined by it's frequency

# %% [markdown]
# # Lecture 5
#
# Given initial conditions, we can solve the Schrödinger Equation to get the wave function over all time.
#
# $$
# i\hbar\frac{\partial}{\partial t} \Psi = \left( \frac{\hat{p}^2}{2m}  + V\right)\Psi
# $$

# %% [markdown]
# # Lecture 6
#
# We have the Schrödinger Equation
#
# $$
# i\hbar\frac{\partial}{\partial t} \Psi = \left( \frac{\hat{p}^2}{2m}  + V\right)\Psi
# $$
#
# The probability density of the position of the particle is $|\Psi^2|$, so we can imagine a probability distribution such as
#
# We can imagine a particle such as ![Screen%20Shot%202023-03-31%20at%206.59.06%20PM.png](attachment:Screen%20Shot%202023-03-31%20at%206.59.06%20PM.png)
#
# However, we should show that time derivative of the magnitude of the wave function.
#
# $$
# N(t) = \int_{-\infty}^\infty{|\Psi(x, t_0)|^2\mathrm{d}x}
# $$
#
# $$
# \frac{\text{d}}{\mathrm{d}t}N(t) = \frac{i}{\hbar}\int{(\hat{H}\Psi)^*\Psi - \Psi^*(\hat{H}\Psi)}\text{d}x
# $$
#
# which would be zero for _Hermitian_ $\hat{H}$
#
# During the derivation, we come across the quantity
#
# $$
# \frac{\partial}{\partial t}
# $$

# %% [markdown]
# # Lecture 7: Wavepackets and Uncertainty
#
# We can write $\Psi$ as
# $$
# \Psi(x, 0) = \frac{1}{\sqrt{2\pi}}\int_{\infty}^\infty{\Phi(k)e^{ikx}\text{d}k}
# $$
#
# We can invert this as
# $$
# \Phi(k) = \frac{1}{\sqrt{2\pi}}\int_{-\infty}^\infty{\Psi(x, 0)e^{-ikx}\text{d}}
# $$
#
# ## Stationary Phase Approximation
#
# The uncertainty in $x$ is related to the uncertainty in $k$.
#
# Reality condition: $\Psi(x, 0)$ is real iff $\Phi^*(-k) = \Phi(k)$
#
# $$
# k = k_0 + \tilde{k}
# $$
#
# $$
# \Psi(x, 0) = \frac{1}{\sqrt{2\pi}}
# $$
#
# Our wavefunction is going to be non-zero where $\Delta k x \approx 1$
#
# $\Delta k \Delta x$
#
# We will have minimal shape change in the wave packet.
#
# $$
# \omega(k) = \omega(k_0) + (k - k_0)\frac{\text{d}\omega}{\text{d}}
# $$
