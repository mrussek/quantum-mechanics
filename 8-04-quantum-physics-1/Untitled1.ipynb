# %% [markdown]
# # <u>Solving the Time-Independent Schrödinger Equation</u>
#
# $$
# \newcommand{\d}[1]{\text{d}#1}
# \newcommand{\td}[2]{\frac{\d{#1}}{\d{#2}}}
# \newcommand{\pd}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\do}[2]{\frac{\text{d}}{\d{#1}}{#2}}
# \newcommand{\pdo}[2]{\frac{\partial}{\partial #1}{#2}}
# \newcommand{\i}[2]{\langle#1|#2\rangle}
# $$
#
# ## <u>Stationary states</u>
#
# $$
# \Psi(x, t) = g(t)\psi(x)
# $$
#
# Insert into Schrödinger Equations
#
# $$
# \begin{align*}
# i \hbar \pd{\Psi}{t} =
# \end{align*}
# $$
